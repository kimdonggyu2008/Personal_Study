# %% [markdown]
# <a href="https://colab.research.google.com/github/kimdonggyu2008/Personal_Study/blob/main/wav2vec2_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/코딩공부/project_folder/fairseq
# Out:
# /content/drive/MyDrive/코딩공부/project_folder/fairseq

# %%
# !pip install -e .
# Out:
# Obtaining file:///content/drive/MyDrive/%E1%84%8F%E1%85%A9%E1%84%83%E1%85%B5%E1%86%BC%E1%84%80%E1%85%A9%E1%86%BC%E1%84%87%E1%85%AE/project_folder/fairseq
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
# WARNING: Ignoring version 2.0.6 of omegaconf since it has invalid metadata:
# Requested omegaconf<2.1 from https://files.pythonhosted.org/packages/d0/eb/9d63ce09dd8aa85767c65668d5414958ea29648a0eec80a4a7d311ec2684/omegaconf-2.0.6-py3-none-any.whl (from fairseq==0.12.2) has invalid metadata: .* suffix can only be used with `==` or `!=` operators
#     PyYAML (>=5.1.*)
#             ~~~~~~^
# Please use pip<24.1 if you need to use this version.
# ...
# WARNING: Ignoring version 2.0.5 of omegaconf since it has invalid metadata:
# ...

# %%
# !pip install soundfile

# %% [markdown]
# # 전처리 데이터 생성

# %%
# !python /content/drive/MyDrive/코딩공부/project_folder/fairseq/examples/wav2vec/wav2vec_manifest.py \
/content/drive/MyDrive/코딩공부/project_folder/project_dataset/LibriSpeech/train-clean-100 \
--dest /content/drive/MyDrive/코딩공부/project_folder/project_dataset/manifest \
--ext flac \
--valid-percent 0.1

# %% [markdown]
# # 실행코드

# %%
# !fairseq-hydra-train \
    task.data=/content/drive/MyDrive/코딩공부/project_folder/project_dataset/LibriSpeech \
    --config-dir /content/drive/MyDrive/코딩공부/project_folder/fairseq/examples/wav2vec/config/pretraining \
    --config-name wav2vec2_base_librispeech
