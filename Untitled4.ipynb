# %% [markdown]
# <a href="https://colab.research.google.com/github/kimdonggyu2008/Personal_Study/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/espnet/espnet.git
# Out:
# Cloning into 'espnet'...
# remote: Enumerating objects: 422694, done.
# remote: Counting objects: 100% (23085/23085), done.
# remote: Compressing objects: 100% (6673/6673), done.
# remote: Total 422694 (delta 22906), reused 16412 (delta 16412), pack-reused 399609 (from 2)
# Receiving objects: 100% (422694/422694), 1.14 GiB | 23.88 MiB/s, done.
# Resolving deltas: 100% (340354/340354), done.
# Updating files: 100% (12566/12566), done.

# %%
cd /content/espnet/egs2/librispeech/asr1
# Out:
# /content/espnet/egs2/librispeech/asr1

# %%
! ./run.sh --stage -1 --stop_stage 3
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# LibriSpeech/train-clean-100/2136/5143/2136-5143-0000.flac
# LibriSpeech/train-clean-100/2136/5143/2136-5143-0036.flac
# LibriSpeech/train-clean-100/2136/5143/2136-5143-0035.flac
# LibriSpeech/train-clean-100/2136/5143/2136-5143-0009.flac
# LibriSpeech/train-clean-100/2136/5143/2136-5143-0030.flac
# LibriSpeech/train-clean-100/2136/5143/2136-5143-0014.flac
# LibriSpeech/train-clean-100/2136/5143/2136-5143-0041.flac
# LibriSpeech/train-clean-100/2136/5143/2136-5143-0008.flac
# LibriSpeech/train-clean-100/2136/5143/2136-5143-0028.flac
# LibriSpeech/train-clean-100/2136/5143/2136-5143-0037.flac
# LibriSpeech/train-clean-100/2136/5143/2136-5143-0040.flac
# LibriSpeech/train-clean-100/2136/5143/2136-5143-0006.flac
# LibriSpeech/train-clean-100/2136/5143/2136-5143-0034.flac
# LibriSpeech/train-clean-100/2136/5143/2136-5143.trans.txt
# LibriSpeech/train-clean-100/2136/5143/2136-5143-0001.flac
# LibriSpeech/train-clean-100/2136/5143/2136-5143-0016.flac
# ...
